# %%
! pip install numpy pandas matplotlib seaborn sklearn
# Out:
# Requirement already satisfied: numpy in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (1.21.5)
# Requirement already satisfied: pandas in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: matplotlib in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: seaborn in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: sklearn in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: scipy>=1.0 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: scikit-learn in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: six>=1.5 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ycclau/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sklearn) (2.2.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Part (A) Feature Selection

# %%
#read X_train first 3 rows for header
df_X_header = pd.read_csv("X_train.csv", dtype = str, nrows = 3,header = None)

#combine df_X_header by row
X_header = []
for ic in range(len(df_X_header.columns)):
    temp = ""
    for ir in range(len(df_X_header)):
        if(ir != 0):
            temp += "&"
        temp += df_X_header.iloc[ir,ic]
    X_header.append(temp)
    


#read X_train csv files except first 3 rows 
X_train = pd.read_csv("X_train.csv",
                         skiprows = 3,
                         header = None)

X_valid = pd.read_csv("X_valid.csv",
                          skiprows = 3,
                          header = None)

#combine header and the data together
X_train.columns = X_header

#read Y_train csv file
Y_train = pd.read_csv("Y_train.csv")
Y_valid = pd.read_csv("Y_valid.csv")

# %%
X_id = X_train.iloc[:,0]
X_feat = X_train.iloc[:,1:]
print(X_train.shape)
print(X_id.shape)
print(X_feat.shape)
print(Y_train.shape)
# Out:
# (16760, 7489)
# (16760,)
# (16760, 7488)
# (16760, 2)

# %%
#Three principle to conduct the features Selection
    #1. Only select the features mean of the variable by time
    #2. Only select the either one feature among the features group with low covariance (< 0.9)
    #3  Only select the features with non-zero weights under Simple Logistic Regression Model with L1 Regularization

# %%
def featureSelectByMean(df_feat,df_header,cols = None):
    if (cols == None):
        cols = np.full((df_feat.shape[1],), False, dtype = bool)
    for ic in range(len(df_header.columns)):
        if (df_header.iloc[1,ic] == "mean"):
            cols[ic] = True
    
    print("Select features with mean value:")
    print("Original:",df_feat.shape[1],"\tSelected:",np.sum(cols_selected))        
    return df_feat.iloc[:,cols]
    

X_feat = featureSelectByMean(X_feat,df_X_header)
X_feat.describe()
# Out:
# Select features with mean value:
# Original: 7488 	Selected: 2496
#        alanine aminotransferase&mean&1  alanine aminotransferase&mean&2  \
# count                     16760.000000                     16760.000000
# mean                         -0.065219                        -0.064588
# std                           0.423142                         0.428927
# min                          -0.279057                        -0.279057
# 25%                          -0.248043                        -0.248043
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                          10.413320                        10.413320
#
#        alanine aminotransferase&mean&3  alanine aminotransferase&mean&4  \
# count                     16760.000000                     16760.000000
# mean                         -0.064803                        -0.064101
# std                           0.427698                         0.435464
# min                          -0.279057                        -0.279057
# 25%                          -0.248043                        -0.248043
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                          10.413320                        10.413320
#
#        alanine aminotransferase&mean&5  alanine aminotransferase&mean&6  \
# count                     16760.000000                     16760.000000
# mean                         -0.064031                        -0.063712
# std                           0.436145                         0.438468
# min                          -0.279057                        -0.279057
# 25%                          -0.248043                        -0.248043
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                          10.413320                        10.413320
#
#        alanine aminotransferase&mean&7  alanine aminotransferase&mean&8  \
# count                     16760.000000                     16760.000000
# mean                         -0.063905                        -0.064175
# std                           0.435569                         0.432840
# min                          -0.279057                        -0.279057
# 25%                          -0.248043                        -0.248043
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                          10.413320                        10.413320
#
#        alanine aminotransferase&mean&9  alanine aminotransferase&mean&10  ...  \
# count                     16760.000000                      16760.000000  ...
# mean                         -0.064640                         -0.064856  ...
# std                           0.426678                          0.420549  ...
# min                          -0.279057                         -0.279057  ...
# 25%                          -0.248043                         -0.248043  ...
# 50%                           0.000000                          0.000000  ...
# 75%                           0.000000                          0.000000  ...
# max                          10.413320                         10.413320  ...
#
#        white blood cell count urine&mean&15  \
# count                          16760.000000
# mean                              -0.000300
# std                                0.339446
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&16  \
# count                          16760.000000
# mean                              -0.000252
# std                                0.338852
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&17  \
# count                          16760.000000
# mean                              -0.000329
# std                                0.338696
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&18  \
# count                          16760.000000
# mean                              -0.000262
# std                                0.338709
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&19  \
# count                          16760.000000
# mean                              -0.000249
# std                                0.338702
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&20  \
# count                          16760.000000
# mean                              -0.000257
# std                                0.338702
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&21  \
# count                          16760.000000
# mean                              -0.000282
# std                                0.338711
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&22  \
# count                          16760.000000
# mean                              -0.000300
# std                                0.338711
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&mean&23  \
# count                          16760.000000
# mean                              -0.000448
# std                                0.338265
# min                               -0.316046
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               11.783246
#
#        white blood cell count urine&time_since_measured&0
# count                                       16760.000000
# mean                                          269.869093
# std                                           315.670695
# min                                             0.000000
# 25%                                            57.000000
# 50%                                           154.000000
# 75%                                           360.000000
# max                                          2232.000000
#
# [8 rows x 2496 columns]

# %%
def featureSelectByCorr(df_feat,threshold = 0.9):
    corr = df_feat.corr()
    
    cols = np.full((corr.shape[0],), True, dtype = bool)
    for i in range(corr.shape[0],0,-1):
        for j in range(i+1, corr.shape[0]):
            if corr.iloc[i,j] >= threshold:
                if(cols[j]):
                    cols[j] = False
    print("Select features by filtering features with high covariance","(>= "+str(threshold)+")",":")
    print("Original:",df_feat.shape[1],"\tSelected:",np.sum(cols))
    
    return df_feat.iloc[:,cols]

X_feat = featureSelectByCorr(X_feat,0.9)
X_feat.describe()
# Out:
# Select features by filtering features with high covariance (>= 0.9) :
# Original: 2496 	Selected: 397
#        alanine aminotransferase&mean&1  alanine aminotransferase&mean&2  \
# count                     16760.000000                     16760.000000
# mean                         -0.065219                        -0.064588
# std                           0.423142                         0.428927
# min                          -0.279057                        -0.279057
# 25%                          -0.248043                        -0.248043
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                          10.413320                        10.413320
#
#        alanine aminotransferase&time_since_measured&0  albumin&mean&1  \
# count                                    16760.000000    16760.000000
# mean                                        33.225000        0.034359
# std                                         38.602299        0.619799
# min                                          0.000000       -3.131888
# 25%                                          0.000000        0.000000
# 50%                                         23.000000        0.000000
# 75%                                         48.000000        0.000000
# max                                        336.000000        3.492301
#
#        albumin&time_since_measured&0  albumin ascites&mean&1  \
# count                   16760.000000            1.676000e+04
# mean                       46.030847            1.848164e-18
# std                        50.040251            5.462116e-02
# min                         0.000000           -1.702985e+00
# 25%                        11.000000            0.000000e+00
# 50%                        25.000000            0.000000e+00
# 75%                        69.000000            0.000000e+00
# max                       480.000000            3.469357e+00
#
#        albumin ascites&time_since_measured&0  albumin pleural&mean&1  \
# count                           16760.000000            16760.000000
# mean                             6915.172375                0.000044
# std                              6261.763074                0.051822
# min                                 0.000000               -2.312068
# 25%                              2157.000000                0.000000
# 50%                              5146.000000                0.000000
# 75%                              9888.000000                0.000000
# max                             31735.000000                1.613770
#
#        albumin pleural&time_since_measured&0  albumin urine&mean&1  ...  \
# count                           16760.000000          1.676000e+04  ...
# mean                             8732.591826          7.286667e-20  ...
# std                              8127.378115          5.516467e-02  ...
# min                                 0.000000         -5.691630e-01  ...
# 25%                              2232.750000          0.000000e+00  ...
# 50%                              6192.000000          0.000000e+00  ...
# 75%                             13056.000000          0.000000e+00  ...
# max                             36853.000000          4.592960e+00  ...
#
#        total protein urine&time_since_measured&0  troponin-i&mean&1  \
# count                               16760.000000       16760.000000
# mean                                 1559.202029          -0.002609
# std                                  1779.006089           0.168234
# min                                     0.000000          -0.692272
# 25%                                   398.000000           0.000000
# 50%                                   984.000000           0.000000
# 75%                                  2034.250000           0.000000
# max                                 11424.000000           3.830272
#
#        troponin-t&mean&1  troponin-t&time_since_measured&0  \
# count       16760.000000                      16760.000000
# mean           -0.025065                         69.243735
# std             0.504190                         85.521628
# min            -0.366371                          0.000000
# 25%             0.000000                         11.000000
# 50%             0.000000                         41.000000
# 75%             0.000000                         96.000000
# max             8.913147                        768.000000
#
#        venous pvo2&mean&1  weight&mean&1  weight&time_since_measured&0  \
# count        16760.000000   16760.000000                  16760.000000
# mean            -0.000489      -0.014655                     27.429415
# std              0.123559       0.812038                     35.051215
# min             -2.765677      -3.517696                      0.000000
# 25%              0.000000      -0.405690                      2.000000
# 50%              0.000000       0.000000                     21.000000
# 75%              0.000000       0.122018                     33.000000
# max              3.207278       7.198578                    431.000000
#
#        white blood cell count&mean&1  white blood cell count urine&mean&1  \
# count                   16760.000000                         16760.000000
# mean                        0.001104                            -0.000158
# std                         0.962887                             0.338099
# min                        -1.160785                            -0.316046
# 25%                        -0.414731                             0.000000
# 50%                        -0.120972                             0.000000
# 75%                         0.228741                             0.000000
# max                        54.802581                            11.783246
#
#        white blood cell count urine&time_since_measured&0
# count                                       16760.000000
# mean                                          269.869093
# std                                           315.670695
# min                                             0.000000
# 25%                                            57.000000
# 50%                                           154.000000
# 75%                                           360.000000
# max                                          2232.000000
#
# [8 rows x 397 columns]

# %%
#Standardlization of features
def XStandardization(df_X):
    res = df_X.copy()
    for i in df_X.columns:
        res[i] = (df_X[i] - np.mean(df_X[i])) / np.std(df_X[i])
    return res
X_feat_std = XStandardization(X_feat)
X_feat_std.describe()
# Out:
#        alanine aminotransferase&mean&1  alanine aminotransferase&mean&2  \
# count                     1.676000e+04                     1.676000e+04
# mean                      1.054483e-15                     4.108223e-16
# std                       1.000030e+00                     1.000030e+00
# min                      -5.053731e-01                    -5.000271e-01
# 25%                      -4.320761e-01                    -4.277187e-01
# 50%                       1.541344e-01                     1.505857e-01
# 75%                       1.541344e-01                     1.505857e-01
# max                       2.476437e+01                     2.442891e+01
#
#        alanine aminotransferase&time_since_measured&0  albumin&mean&1  \
# count                                    1.676000e+04    1.676000e+04
# mean                                     1.504727e-15    1.275090e-15
# std                                      1.000030e+00    1.000030e+00
# min                                     -8.607257e-01   -5.108659e+00
# 25%                                     -8.607257e-01   -5.543674e-02
# 50%                                     -2.648885e-01   -5.543674e-02
# 75%                                      3.827606e-01   -5.543674e-02
# max                                      7.843679e+00    5.579303e+00
#
#        albumin&time_since_measured&0  albumin ascites&mean&1  \
# count                   1.676000e+04            1.676000e+04
# mean                    8.096296e-16            3.648299e-17
# std                     1.000030e+00            1.000030e+00
# min                    -9.199039e-01           -3.117905e+01
# 25%                    -7.000743e-01           -3.383704e-17
# 50%                    -4.202912e-01           -3.383704e-17
# 75%                     4.590272e-01           -3.383704e-17
# max                     8.672660e+00            6.351861e+01
#
#        albumin ascites&time_since_measured&0  albumin pleural&mean&1  \
# count                           1.676000e+04            1.676000e+04
# mean                            5.229177e-17           -3.485518e-16
# std                             1.000030e+00            1.000030e+00
# min                            -1.104382e+00           -4.461811e+01
# 25%                            -7.599001e-01           -8.540350e-04
# 50%                            -2.825443e-01           -8.540350e-04
# 75%                             4.747730e-01           -8.540350e-04
# max                             3.963831e+00            3.114096e+01
#
#        albumin pleural&time_since_measured&0  albumin urine&mean&1  ...  \
# count                           1.676000e+04          1.676000e+04  ...
# mean                           -1.615255e-16         -2.530382e-19  ...
# std                             1.000030e+00          1.000030e+00  ...
# min                            -1.074498e+00         -1.031784e+01  ...
# 25%                            -7.997703e-01         -1.320933e-18  ...
# 50%                            -3.126061e-01         -1.320933e-18  ...
# 75%                             5.319719e-01         -1.320933e-18  ...
# max                             3.460064e+00          8.326157e+01  ...
#
#        total protein urine&time_since_measured&0  troponin-i&mean&1  \
# count                               1.676000e+04       1.676000e+04
# mean                               -4.767467e-17       1.923181e-16
# std                                 1.000030e+00       1.000030e+00
# min                                -8.764717e-01      -4.099543e+00
# 25%                                -6.527446e-01       1.551132e-02
# 50%                                -3.233374e-01       1.551132e-02
# 75%                                 2.670380e-01       1.551132e-02
# max                                 5.545283e+00       2.278370e+01
#
#        troponin-t&mean&1  troponin-t&time_since_measured&0  \
# count       1.676000e+04                      1.676000e+04
# mean       -1.040717e-14                     -2.994771e-15
# std         1.000030e+00                      1.000030e+00
# min        -6.769595e-01                     -8.096876e-01
# 25%         4.971496e-02                     -6.810613e-01
# 50%         4.971496e-02                     -3.302624e-01
# 75%         4.971496e-02                      3.128690e-01
# max         1.772839e+01                      8.170765e+00
#
#        venous pvo2&mean&1  weight&mean&1  weight&time_since_measured&0  \
# count        1.676000e+04   1.676000e+04                  1.676000e+04
# mean         4.781891e-16   7.985657e-16                  5.016837e-15
# std          1.000030e+00   1.000030e+00                  1.000030e+00
# min         -2.238018e+01  -4.314014e+00                 -7.825758e-01
# 25%          3.954402e-03  -4.815618e-01                 -7.255148e-01
# 50%          3.954402e-03   1.804747e-02                 -1.834346e-01
# 75%          3.954402e-03   1.683128e-01                  1.589318e-01
# max          2.596220e+01   8.883136e+00                  1.151408e+01
#
#        white blood cell count&mean&1  white blood cell count urine&mean&1  \
# count                   1.676000e+04                         1.676000e+04
# mean                   -2.853061e-17                         3.465015e-15
# std                     1.000030e+00                         1.000030e+00
# min                    -1.206708e+00                        -9.343373e-01
# 25%                    -4.318755e-01                         4.659175e-04
# 50%                    -1.267854e-01                         4.659175e-04
# 75%                     2.364172e-01                         4.659175e-04
# max                     5.691539e+01                         3.485300e+01
#
#        white blood cell count urine&time_since_measured&0
# count                                       1.676000e+04
# mean                                        2.369258e-14
# std                                         1.000030e+00
# min                                        -8.549325e-01
# 25%                                        -6.743592e-01
# 50%                                        -3.670678e-01
# 75%                                         2.855305e-01
# max                                         6.215938e+00
#
# [8 rows x 397 columns]

# %%
#visualizing the features to check its distribution to determine whether normalization or standardization is more suitable for feature scaling

check_ID = 326

sns.displot(X_feat_std.iloc[:,check_ID], color = 'g', kde  = True).set(title = X_feat_corr.columns[check_ID])

plt.show()

# %%
from sklearn.linear_model import LogisticRegression

C = [1e-3,2e-3,3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2,1.1e-2,1.2e-2,1.3e-2,1.4e-2]

def CheckSelectBySLR_L1(df_feat_std,Y_train,C):
    
    print("Features selected after applying SLR model with L1 regularization:")
    n_feat = []
    for n_c in C:
        clf = LogisticRegression(penalty = 'l1',C = n_c, solver = 'liblinear')
        clf.fit(X_feat_std,Y_train.iloc[:,1])
    
        cols_l1 = []
        for i in range(clf.coef_.shape[1]):
            if clf.coef_[0,i] != 0.0:
                cols_l1.append(True)
            else:
                cols_l1.append(False)
        n_feat.append(np.sum(cols_l1))
        print("L1 C value:",n_c, "\tNumber of features:",clf.coef_.shape[1], "\tSelected:",np.sum(cols_l1))
    
    nc_log = list(map(np.log10,C))
    plt.plot(nc_log, n_feat, marker = "o",color = "g")

CheckSelectBySLR_L1(X_feat_std,Y_train,C)
# Out:
# Features selected after applying SLR model with L1 regularization:
# L1 C value: 0.001 	Number of features: 397 	Selected: 0
# L1 C value: 0.002 	Number of features: 397 	Selected: 5
# L1 C value: 0.003 	Number of features: 397 	Selected: 12
# L1 C value: 0.004 	Number of features: 397 	Selected: 23
# L1 C value: 0.005 	Number of features: 397 	Selected: 29
# L1 C value: 0.006 	Number of features: 397 	Selected: 37
# L1 C value: 0.007 	Number of features: 397 	Selected: 42
# L1 C value: 0.008 	Number of features: 397 	Selected: 44
# L1 C value: 0.009 	Number of features: 397 	Selected: 50
# L1 C value: 0.01 	Number of features: 397 	Selected: 55
# L1 C value: 0.011 	Number of features: 397 	Selected: 62
# L1 C value: 0.012 	Number of features: 397 	Selected: 66
# L1 C value: 0.013 	Number of features: 397 	Selected: 70
# L1 C value: 0.014 	Number of features: 397 	Selected: 75
